# %% [markdown]
# ### Описание задания:
# Обучить свёрточную сеть для классификации изображений на данных CIFAR10.
#
# ### Задачи:
#
# 1) Минимизировать многоклассовую кроссэнтропию с помощью sgd. Получить сеть, которая достигнет не менее 45% accuracy на тестовых данных. Поскольку в y_train лежат номера классов, Keras нужно либо указать sparse функции потерь и метрики оценки качества классификации (sparse_categorical_crossentropy и sparse_categorical_accuracy), либо конвертировать метки в one-hot формат.
# 2) Реализуйте небольшую свёрточную сеть:
# - Входной слой
# - Свёртка 3x3 с 10 фильтрами
# - Нелинейность на ваш вкус
# - Max-pooling 2x2
# - Вытягиваем оставшееся в вектор (Flatten)
# - Полносвязный слой на 100 нейронов
# - Нелинейность на ваш вкус
# - Выходной полносвязный слой с softmax
# - Обучите её так же, как и предыдущую сеть. Если всё хорошо, у вас получится accuracy не меньше 50%.
# 3) Использовать различные методы оптимизации (sgd, momentum, adam) с параметрами по умолчанию. Определить какой из методов работает лучше.
# 4) Добавить нормализацию по батчу (BatchNormalization) между свёрткой и активацией. Попробовать использовать несколько нормализаций — в свёрточных и полносвязных слоях.
# 5) Посмотреть на batch_size (параметр model.fit) - при большем батче модель будет быстрее проходить эпохи, но с совсем огромным батчом вам потребуется больше эпох для сходимости (т.к. сеть делает меньше шагов за одну эпоху). Найти такое значение, при котором модель быстрее достигает точности 55%.
# 6) Попробовать найти такую комбинацию метода обучения и нормализации, при которой сеть имеет наилучшую кривую обучения. Пояснить, что вы понимаете под "наилучшей" кривой обучения.
# 7) Обучить большую свёрточную сеть, которая даст на тестовой выборке accuracy больше 80%. В этом задании требуется провести эксперименты, сравнив их между собой в конце.

# %%
import keras
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from collections import OrderedDict

from keras import backend
from keras import layers
from keras.datasets import cifar10
from keras.models import Sequential

from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm

# %% [markdown]
# ### Загрузка данных

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=10**4, random_state=21)

class_names = np.array(['airplane','automobile ','bird ','cat ','deer ','dog ','frog ','horse ','ship ','truck'])

print (X_train.shape,y_train.shape)
# Out:
# (40000, 32, 32, 3) (40000, 1)

# %%
plt.figure(figsize=[12,10])
for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.xlabel(class_names[y_train[i, 0]])
    plt.imshow(X_train[i])

# %% [markdown]
# ### Подготовка данных
#
# Преобразуем каждый пиксель изображения из кодировки тройкой чисел (RGB) от 0 до 255 в диапазон данных [0, 1].

# %%
X_train = X_train / 255
X_val = X_val / 255
X_test = X_test / 255

# %%
assert np.shape(X_train) == (40000, 32, 32, 3), "data shape should not change"
assert 0.9 <= max(map(np.max, (X_train, X_val, X_test))) <= 1.05
assert 0.0 <= min(map(np.min, (X_train, X_val, X_test))) <= 0.1
assert len(np.unique(X_test / 255.)) > 10, "make sure you casted data to float type"

# %% [markdown]
# ### 0. Создание простой нейросети:
#
# - принимает на вход картинки размера 32 x 32 x 3;
# - вытягивает их в вектор (keras.layers.Flatten);
# - пропускает через 1 или 2 полносвязных слоя;
# - выходной слой отдает вероятности принадлежности к каждому из 10 классов.

# %%
model = Sequential()
model.add(layers.Flatten(input_shape=(32, 32, 3)))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
dummy_pred = model.predict(X_train[:20])
assert dummy_pred.shape == (20, 10)
assert np.allclose(dummy_pred.sum(-1), 1)
print("Успех!")
# Out:
# 1/1 [==============================] - 0s 302ms/step
# Успех!

# %% [markdown]
# ### 1. Минимизация многоклассовой кроссэнтропии с помощью sgd. Получение сети, которая достигнет не менее 45% accuracy

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes=None)
y_val = tf.keras.utils.to_categorical(y_val, num_classes=None)

# %%
y_train.shape, y_val.shape
# Out:
# ((40000, 10), (10000, 10))

# %% [markdown]
# #### Подключение callbacks

# %%
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(monitor='loss', patience=3),
    keras.callbacks.LearningRateScheduler(scheduler),
    keras.callbacks.TensorBoard(log_dir='./logs'),
]

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 32)                98336
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 99,722
# Trainable params: 99,722
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,
          y_train,
          batch_size=32,
          validation_split=0.2,
          verbose=2,
          epochs=20,
          callbacks = callbacks,
          validation_data=[X_val, y_val])
# Out:
# Epoch 1/20
# 1250/1250 - 10s - loss: 2.0043 - accuracy: 0.2639 - val_loss: 1.8657 - val_accuracy: 0.3376 - lr: 0.0100 - 10s/epoch - 8ms/step
# Epoch 2/20
# 1250/1250 - 7s - loss: 1.8311 - accuracy: 0.3467 - val_loss: 1.7715 - val_accuracy: 0.3735 - lr: 0.0100 - 7s/epoch - 6ms/step
# Epoch 3/20
# 1250/1250 - 6s - loss: 1.7645 - accuracy: 0.3705 - val_loss: 1.7503 - val_accuracy: 0.3778 - lr: 0.0100 - 6s/epoch - 5ms/step
# Epoch 4/20
# 1250/1250 - 6s - loss: 1.7213 - accuracy: 0.3899 - val_loss: 1.7026 - val_accuracy: 0.3973 - lr: 0.0100 - 6s/epoch - 5ms/step
# Epoch 5/20
# 1250/1250 - 8s - loss: 1.6875 - accuracy: 0.4006 - val_loss: 1.6854 - val_accuracy: 0.4003 - lr: 0.0100 - 8s/epoch - 6ms/step
# Epoch 6/20
# 1250/1250 - 7s - loss: 1.6613 - accuracy: 0.4106 - val_loss: 1.6998 - val_accuracy: 0.4034 - lr: 0.0100 - 7s/epoch - 6ms/step
# Epoch 7/20
# 1250/1250 - 6s - loss: 1.6365 - accuracy: 0.4202 - val_loss: 1.6251 - val_accuracy: 0.4278 - lr: 0.0100 - 6s/epoch - 5ms/step
# Epoch 8/20
# 1250/1250 - 7s - loss: 1.6154 - accuracy: 0.4273 - val_loss: 1.6174 - val_accuracy: 0.4340 - lr: 0.0100 - 7s/epoch - 6ms/step
# Epoch 9/20
# 1250/1250 - 8s - loss: 1.5988 - accuracy: 0.4344 - val_loss: 1.6276 - val_accuracy: 0.4209 - lr: 0.0100 - 8s/epoch - 6ms/step
# Epoch 10/20
# 1250/1250 - 7s - loss: 1.5802 - accuracy: 0.4384 - val_loss: 1.5963 - val_accuracy: 0.4329 - lr: 0.0100 - 7s/epoch - 6ms/step
# Epoch 11/20
# 1250/1250 - 11s - loss: 1.5573 - accuracy: 0.4478 - val_loss: 1.5967 - val_accuracy: 0.4384 - lr: 0.0090 - 11s/epoch - 8ms/step
# Epoch 12/20
# 1250/1250 - 8s - loss: 1.5383 - accuracy: 0.4545 - val_loss: 1.5853 - val_accuracy: 0.4409 - lr: 0.0082 - 8s/epoch - 6ms/step
# Epoch 13/20
# 1250/1250 - 7s - loss: 1.5217 - accuracy: 0.4624 - val_loss: 1.5694 - val_accuracy: 0.4501 - lr: 0.0074 - 7s/epoch - 5ms/step
# Epoch 14/20
# 1250/1250 - 7s - loss: 1.5057 - accuracy: 0.4669 - val_loss: 1.5478 - val_accuracy: 0.4516 - lr: 0.0067 - 7s/epoch - 5ms/step
# Epoch 15/20
# 1250/1250 - 6s - loss: 1.4929 - accuracy: 0.4718 - val_loss: 1.5838 - val_accuracy: 0.4411 - lr: 0.0061 - 6s/epoch - 5ms/step
# Epoch 16/20
# 1250/1250 - 6s - loss: 1.4815 - accuracy: 0.4754 - val_loss: 1.5194 - val_accuracy: 0.4634 - lr: 0.0055 - 6s/epoch - 5ms/step
# Epoch 17/20
# 1250/1250 - 7s - loss: 1.4686 - accuracy: 0.4794 - val_loss: 1.5169 - val_accuracy: 0.4649 - lr: 0.0050 - 7s/epoch - 5ms/step
# Epoch 18/20
# 1250/1250 - 7s - loss: 1.4582 - accuracy: 0.4835 - val_loss: 1.5055 - val_accuracy: 0.4693 - lr: 0.0045 - 7s/epoch - 6ms/step
# Epoch 19/20
# 1250/1250 - 6s - loss: 1.4482 - accuracy: 0.4872 - val_loss: 1.5302 - val_accuracy: 0.4574 - lr: 0.0041 - 6s/epoch - 5ms/step
# Epoch 20/20
# 1250/1250 - 6s - loss: 1.4404 - accuracy: 0.4871 - val_loss: 1.5099 - val_accuracy: 0.4667 - lr: 0.0037 - 6s/epoch - 5ms/step

# %%
from sklearn.metrics import accuracy_score
y_pred = [np.argmax(prob) for prob in model.predict(X_test)]
test_acc = accuracy_score(y_test, y_pred)
print("\n Test_acc =", test_acc)
assert test_acc > 0.45, "Not good enough. Back to the drawing board :)"
# Out:
# 313/313 [==============================] - 2s 4ms/step
#
#  Test_acc = 0.465

# %% [markdown]
# **Вывод:** простой моделью нейросети с использование метода оптимизации SGD была достигнута необходимая accuracy выше 45%

# %% [markdown]
# ### 2. Реализация небольшой свёрточной сети
#
# **Требования:**
# - Входной слой
# - Свёртка 3x3 с 10 фильтрами
# - Нелинейность по выбору
# - Max-pooling 2x2
# - Вытягиваем оставшееся в вектор (Flatten)
# - Полносвязный слой на 100 нейронов
# - Нелинейность по выбору
# - Выходной полносвязный слой с softmax

# %%
conv_model = Sequential([
    layers.Conv2D(filters=10,
                           kernel_size=(3, 3),
                           padding='same',
                           activation='relu',
                           input_shape=(32, 32, 3)),
    layers.MaxPool2D(pool_size=(2, 2), padding='valid'),
    layers.Flatten(),
    layers.Dense(100, activation='relu'),
    layers.Dense(10, activation='softmax')])

# %%
conv_model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

# %%
conv_model.fit(X_train,
               y_train,
               batch_size=32,
               validation_split=0.2,
               verbose=2,
               epochs=20,
               callbacks = callbacks,
               validation_data=[X_val, y_val])
# Out:
# Epoch 1/20
# 1250/1250 - 18s - loss: 1.9519 - accuracy: 0.3026 - val_loss: 1.7602 - val_accuracy: 0.3729 - lr: 0.0100 - 18s/epoch - 14ms/step
# Epoch 2/20
# 1250/1250 - 18s - loss: 1.6504 - accuracy: 0.4169 - val_loss: 1.5668 - val_accuracy: 0.4419 - lr: 0.0100 - 18s/epoch - 15ms/step
# Epoch 3/20
# 1250/1250 - 18s - loss: 1.4862 - accuracy: 0.4757 - val_loss: 1.4263 - val_accuracy: 0.4980 - lr: 0.0100 - 18s/epoch - 15ms/step
# Epoch 4/20
# 1250/1250 - 18s - loss: 1.3780 - accuracy: 0.5109 - val_loss: 1.3463 - val_accuracy: 0.5274 - lr: 0.0100 - 18s/epoch - 14ms/step
# Epoch 5/20
# 1250/1250 - 19s - loss: 1.3116 - accuracy: 0.5342 - val_loss: 1.3075 - val_accuracy: 0.5356 - lr: 0.0100 - 19s/epoch - 15ms/step
# Epoch 6/20
# 1250/1250 - 20s - loss: 1.2603 - accuracy: 0.5520 - val_loss: 1.2941 - val_accuracy: 0.5388 - lr: 0.0100 - 20s/epoch - 16ms/step
# Epoch 7/20
# 1250/1250 - 24s - loss: 1.2244 - accuracy: 0.5679 - val_loss: 1.2486 - val_accuracy: 0.5588 - lr: 0.0100 - 24s/epoch - 19ms/step
# Epoch 8/20
# 1250/1250 - 19s - loss: 1.1899 - accuracy: 0.5806 - val_loss: 1.2269 - val_accuracy: 0.5691 - lr: 0.0100 - 19s/epoch - 15ms/step
# Epoch 9/20
# 1250/1250 - 21s - loss: 1.1582 - accuracy: 0.5908 - val_loss: 1.2232 - val_accuracy: 0.5724 - lr: 0.0100 - 21s/epoch - 17ms/step
# Epoch 10/20
# 1250/1250 - 28s - loss: 1.1292 - accuracy: 0.6037 - val_loss: 1.1913 - val_accuracy: 0.5839 - lr: 0.0100 - 28s/epoch - 22ms/step
# Epoch 11/20
# 1250/1250 - 28s - loss: 1.0911 - accuracy: 0.6173 - val_loss: 1.1953 - val_accuracy: 0.5809 - lr: 0.0090 - 28s/epoch - 23ms/step
# Epoch 12/20
# 1250/1250 - 20s - loss: 1.0613 - accuracy: 0.6269 - val_loss: 1.1736 - val_accuracy: 0.5942 - lr: 0.0082 - 20s/epoch - 16ms/step
# Epoch 13/20
# 1250/1250 - 21s - loss: 1.0345 - accuracy: 0.6383 - val_loss: 1.1762 - val_accuracy: 0.5876 - lr: 0.0074 - 21s/epoch - 17ms/step
# Epoch 14/20
# 1250/1250 - 20s - loss: 1.0083 - accuracy: 0.6446 - val_loss: 1.1615 - val_accuracy: 0.5983 - lr: 0.0067 - 20s/epoch - 16ms/step
# Epoch 15/20
# 1250/1250 - 19s - loss: 0.9833 - accuracy: 0.6553 - val_loss: 1.1450 - val_accuracy: 0.6060 - lr: 0.0061 - 19s/epoch - 15ms/step
# Epoch 16/20
# 1250/1250 - 19s - loss: 0.9617 - accuracy: 0.6637 - val_loss: 1.1404 - val_accuracy: 0.6059 - lr: 0.0055 - 19s/epoch - 15ms/step
# Epoch 17/20
# 1250/1250 - 18s - loss: 0.9436 - accuracy: 0.6691 - val_loss: 1.1589 - val_accuracy: 0.6012 - lr: 0.0050 - 18s/epoch - 15ms/step
# Epoch 18/20
# 1250/1250 - 24s - loss: 0.9233 - accuracy: 0.6779 - val_loss: 1.1358 - val_accuracy: 0.6119 - lr: 0.0045 - 24s/epoch - 19ms/step
# Epoch 19/20
# 1250/1250 - 18s - loss: 0.9065 - accuracy: 0.6846 - val_loss: 1.1466 - val_accuracy: 0.6080 - lr: 0.0041 - 18s/epoch - 14ms/step
# Epoch 20/20
# 1250/1250 - 22s - loss: 0.8901 - accuracy: 0.6899 - val_loss: 1.1313 - val_accuracy: 0.6082 - lr: 0.0037 - 22s/epoch - 18ms/step

# %%
y_pred = [np.argmax(prob) for prob in conv_model.predict(X_test)]
test_acc = accuracy_score(y_test, y_pred)
print("\n Test_acc =", test_acc)
assert test_acc > 0.50, "Not good enough. Back to the drawing board :)"
# Out:
# 313/313 [==============================] - 3s 10ms/step
#
#  Test_acc = 0.602

# %% [markdown]
# **Вывод:** небольшой свёрточной сетью с аналогичными предудущему этапу параметрами была достигнута необходимая accuracy выше 50%

# %% [markdown]
# ### 3. Использование различных методов оптимизации (sgd, momentum, adam) с параметрами по умолчанию

# %% [markdown]
# Создание стендовой модели для тестирования параметров

# %%
test_model = Sequential([
    layers.Conv2D(filters=10,
                           kernel_size=(3, 3),
                           padding='same',
                           activation='relu',
                           input_shape=(32, 32, 3)),
    layers.MaxPool2D(pool_size=(2, 2), padding='valid'),
    layers.Flatten(),
    layers.Dense(100, activation='relu'),
    layers.Dense(10, activation='softmax')])

# %%
class Evaluator(list):
    def __init__(self, models, optimizers='adam', loss=keras.losses.categorical_crossentropy,
                 metrics=[keras.metrics.categorical_accuracy]):
        '''
            models: dict {name: model}
            optimizers: list of optimizers or just one optimizer
        '''
        if not isinstance(models, dict):
            models = {'single_model': models}
        if not isinstance(optimizers, dict):
            optimizers = {str(optimizers.__class__): optimizers}
        super().__init__([(model_name, keras.models.clone_model(model), optimizer_name, optimizer)
                          for model_name, model in models.items()
                          for optimizer_name, optimizer in optimizers.items()])
        for _, model, _, optimizer in self:
            model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
        self.history = []
            
    def fit(self, X, y, validation_data=(), max_epochs=30, verbose=0, callbacks=[], batch_size=32):
        if not isinstance(callbacks, list):
            callbacks = [callbacks]
        for model_name, model, optimizer_name, optimizer in tqdm(self):
            history = model.fit(X, y, validation_data=validation_data or None, epochs=max_epochs, verbose=verbose,
                      batch_size=batch_size, callbacks=callbacks + [keras.callbacks.TensorBoard(
                          log_dir='./logs/{}_{}'.format(model_name, optimizer_name))])
            self.history.append(history)

    def fit_generator(self, X, y, validation_data=(), max_epochs=30, verbose=1, callbacks=[], batch_size=32):
        datagen = keras.preprocessing.image.ImageDataGenerator(
            rotation_range=20,
            width_shift_range=0.2,
            height_shift_range=0.2,
            horizontal_flip=True
        )
        if not isinstance(callbacks, list):
            callbacks = [callbacks]
        for model_name, model, optimizer_name, optimizer in tqdm(self):
            model.fit_generator(datagen.flow(X, y, batch_size=batch_size), epochs=max_epochs,
                validation_data=validation_data or None, verbose=verbose,
                callbacks=callbacks + [keras.callbacks.TensorBoard(
                    log_dir='./logs/{}_{}'.format(model_name, optimizer_name))])
        
    def evaluate(self, X, y, metric):
        for model_name, model, optimizer_name, _ in self:
            print('Final score of {}_{} is {}'.format(model_name, optimizer_name,
                  metric(y_test, [np.argmax(prob) for prob in model.predict(X_test)])))
            
    def get_history(self):
        return self.history

# %% [markdown]
# Обучение стендовой модели с разными параметрами оптимизации

# %%
optimizers = {
    'sgd': 'sgd',
    'momentum': 'rmsprop',
    'adam': 'adam',
}

# %%
# !rmdir /s /q logs

# %%
evaluator = Evaluator(test_model, optimizers=optimizers)
evaluator.fit(X_train, y_train, validation_data=(X_val, y_val))
evaluator.evaluate(X_test, y_test, accuracy_score)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 313/313 [==============================] - 2s 7ms/step
# Final score of single_model_sgd is 0.6078
# 313/313 [==============================] - 2s 7ms/step
# Final score of single_model_momentum is 0.5955
# 313/313 [==============================] - 3s 7ms/step
# Final score of single_model_adam is 0.5851

# %%
# %load_ext tensorboard
#%reload_ext tensorboard

# %%
# %tensorboard --logdir logs

# %% [markdown]
# **Вывод:** Метод оптимизации SGD для epochs=30 показал самый лучший accuracy = 0.6078

# %% [markdown]
# ### 4. Добавление нормализации по батчу (BatchNormalization) между свёрткой и активацией. Используем несколько нормализаций — в свёрточных и полносвязных слоях.

# %% [markdown]
# В качестве метода оптимизации для нейросети применён RMSprop, который показал лучшее значение accuracy на предудущем этапе.

# %%
callback = [
    keras.callbacks.EarlyStopping(
    monitor ="val_accuracy",
    patience=3,
    verbose=2,
    mode="max",
    restore_best_weights=True)]

# %%
conv_model_batch_norn_1 = Sequential([
    layers.Conv2D(filters=10,
                  kernel_size=(3, 3),
                  padding='same',
                  activation='relu',
                  input_shape=(32, 32, 3)),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size=(2, 2), padding='valid'),
    layers.BatchNormalization(),
    layers.Flatten(),
    layers.Dense(100, activation='relu'),
    layers.Dense(10, activation='softmax')])

# %%
conv_model_batch_norn_2 = Sequential([
    layers.Conv2D(filters=10,
                  kernel_size=(3, 3),
                  padding='same',
                  activation='relu',
                  input_shape=(32, 32, 3)),
    layers.MaxPool2D(pool_size=(2, 2), padding='valid'),
    layers.Flatten(),
    layers.Dense(100, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(10, activation='softmax')])

# %%
conv_model_batch_norn_3 = Sequential([
    layers.Conv2D(filters=10,
                  kernel_size=(3, 3),
                  padding='same',
                  activation='relu',
                  input_shape=(32, 32, 3)),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size=(2, 2), padding='valid'),
    layers.BatchNormalization(),
    layers.Flatten(),
    layers.Dense(100, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(10, activation='softmax')])

# %%
conv_model_batch_norn = [conv_model_batch_norn_1, conv_model_batch_norn_2, conv_model_batch_norn_3]
conv_model_names = [
    'BatchNormalization в свёрточном слое',
    'BatchNormalization в полносвязном слое',
    'BatchNormalization в обоих слоях',
]

# %%
for ind, val in enumerate(conv_model_batch_norn):
    val.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
                loss='categorical_crossentropy',
                metrics=['accuracy'])
    val.fit(X_train,
            y_train,
            batch_size=32,
            validation_split=0.2,
            verbose=2,
            epochs=20,
            callbacks = callback,
            validation_data=[X_val, y_val])
    y_pred = [np.argmax(prob) for prob in val.predict(X_test)]
    test_acc = accuracy_score(y_test, y_pred)
    print(f"\n Test_acc для {conv_model_names[ind]} = ", test_acc)
    assert test_acc > 0.5, "Not good enough. Back to the drawing board :)"
# Out:
# Epoch 1/20
# 1250/1250 - 43s - loss: 1.5993 - accuracy: 0.4315 - val_loss: 1.4280 - val_accuracy: 0.4869 - 43s/epoch - 34ms/step
# Epoch 2/20
# 1250/1250 - 45s - loss: 1.2825 - accuracy: 0.5467 - val_loss: 1.3449 - val_accuracy: 0.5297 - 45s/epoch - 36ms/step
# Epoch 3/20
# 1250/1250 - 41s - loss: 1.1580 - accuracy: 0.5918 - val_loss: 1.2715 - val_accuracy: 0.5541 - 41s/epoch - 33ms/step
# Epoch 4/20
# 1250/1250 - 36s - loss: 1.0660 - accuracy: 0.6269 - val_loss: 1.2085 - val_accuracy: 0.5736 - 36s/epoch - 29ms/step
# Epoch 5/20
# 1250/1250 - 35s - loss: 0.9847 - accuracy: 0.6565 - val_loss: 1.2143 - val_accuracy: 0.5797 - 35s/epoch - 28ms/step
# Epoch 6/20
# 1250/1250 - 36s - loss: 0.9139 - accuracy: 0.6813 - val_loss: 1.2090 - val_accuracy: 0.5861 - 36s/epoch - 29ms/step
# Epoch 7/20
# 1250/1250 - 37s - loss: 0.8434 - accuracy: 0.7070 - val_loss: 1.2178 - val_accuracy: 0.5979 - 37s/epoch - 30ms/step
# Epoch 8/20
# 1250/1250 - 36s - loss: 0.7786 - accuracy: 0.7294 - val_loss: 1.1790 - val_accuracy: 0.6122 - 36s/epoch - 29ms/step
# Epoch 9/20
# 1250/1250 - 36s - loss: 0.7159 - accuracy: 0.7529 - val_loss: 1.3123 - val_accuracy: 0.5830 - 36s/epoch - 29ms/step
# Epoch 10/20
# 1250/1250 - 36s - loss: 0.6593 - accuracy: 0.7710 - val_loss: 1.2900 - val_accuracy: 0.5978 - 36s/epoch - 29ms/step
# Epoch 11/20
# Restoring model weights from the end of the best epoch: 8.
# 1250/1250 - 38s - loss: 0.6014 - accuracy: 0.7911 - val_loss: 1.4742 - val_accuracy: 0.5637 - 38s/epoch - 31ms/step
# Epoch 11: early stopping
# 313/313 [==============================] - 4s 11ms/step
#
#  Test_acc для BatchNormalization в свёрточном слое =  0.6038
# Epoch 1/20
# 1250/1250 - 39s - loss: 1.6416 - accuracy: 0.4170 - val_loss: 1.4403 - val_accuracy: 0.4913 - 39s/epoch - 31ms/step
# Epoch 2/20
# 1250/1250 - 23s - loss: 1.3449 - accuracy: 0.5216 - val_loss: 1.3688 - val_accuracy: 0.5113 - 23s/epoch - 18ms/step
# Epoch 3/20
# 1250/1250 - 20s - loss: 1.2456 - accuracy: 0.5579 - val_loss: 1.6796 - val_accuracy: 0.4486 - 20s/epoch - 16ms/step
# Epoch 4/20
# 1250/1250 - 21s - loss: 1.1718 - accuracy: 0.5859 - val_loss: 1.3253 - val_accuracy: 0.5336 - 21s/epoch - 17ms/step
# Epoch 5/20
# 1250/1250 - 21s - loss: 1.1156 - accuracy: 0.6054 - val_loss: 1.3069 - val_accuracy: 0.5461 - 21s/epoch - 17ms/step
# Epoch 6/20
# 1250/1250 - 19s - loss: 1.0706 - accuracy: 0.6212 - val_loss: 1.4627 - val_accuracy: 0.5199 - 19s/epoch - 15ms/step
# Epoch 7/20
# 1250/1250 - 19s - loss: 1.0309 - accuracy: 0.6367 - val_loss: 1.2777 - val_accuracy: 0.5566 - 19s/epoch - 15ms/step
# Epoch 8/20
# 1250/1250 - 19s - loss: 0.9996 - accuracy: 0.6492 - val_loss: 1.1768 - val_accuracy: 0.5916 - 19s/epoch - 15ms/step
# Epoch 9/20
# 1250/1250 - 19s - loss: 0.9650 - accuracy: 0.6609 - val_loss: 1.1862 - val_accuracy: 0.5898 - 19s/epoch - 15ms/step
# Epoch 10/20
# 1250/1250 - 19s - loss: 0.9385 - accuracy: 0.6681 - val_loss: 1.1630 - val_accuracy: 0.6000 - 19s/epoch - 15ms/step
# Epoch 11/20
# 1250/1250 - 18s - loss: 0.9116 - accuracy: 0.6799 - val_loss: 1.2357 - val_accuracy: 0.5616 - 18s/epoch - 14ms/step
# Epoch 12/20
# 1250/1250 - 18s - loss: 0.8845 - accuracy: 0.6884 - val_loss: 1.2873 - val_accuracy: 0.5842 - 18s/epoch - 14ms/step
# Epoch 13/20
# Restoring model weights from the end of the best epoch: 10.
# 1250/1250 - 18s - loss: 0.8604 - accuracy: 0.6959 - val_loss: 1.2974 - val_accuracy: 0.5708 - 18s/epoch - 14ms/step
# Epoch 13: early stopping
# 313/313 [==============================] - 3s 9ms/step
#
#  Test_acc для BatchNormalization в полносвязном слое =  0.606
# Epoch 1/20
# 1250/1250 - 39s - loss: 1.5805 - accuracy: 0.4402 - val_loss: 1.5296 - val_accuracy: 0.4673 - 39s/epoch - 32ms/step
# Epoch 2/20
# 1250/1250 - 39s - loss: 1.2922 - accuracy: 0.5450 - val_loss: 1.2854 - val_accuracy: 0.5427 - 39s/epoch - 31ms/step
# Epoch 3/20
# 1250/1250 - 36s - loss: 1.1716 - accuracy: 0.5849 - val_loss: 1.2790 - val_accuracy: 0.5612 - 36s/epoch - 29ms/step
# Epoch 4/20
# 1250/1250 - 40s - loss: 1.0868 - accuracy: 0.6188 - val_loss: 1.1494 - val_accuracy: 0.5970 - 40s/epoch - 32ms/step
# Epoch 5/20
# 1250/1250 - 35s - loss: 1.0212 - accuracy: 0.6425 - val_loss: 1.1760 - val_accuracy: 0.5865 - 35s/epoch - 28ms/step
# Epoch 6/20
# 1250/1250 - 38s - loss: 0.9735 - accuracy: 0.6593 - val_loss: 1.2509 - val_accuracy: 0.5672 - 38s/epoch - 30ms/step
# Epoch 7/20
# Restoring model weights from the end of the best epoch: 4.
# 1250/1250 - 36s - loss: 0.9213 - accuracy: 0.6778 - val_loss: 1.4620 - val_accuracy: 0.5341 - 36s/epoch - 29ms/step
# Epoch 7: early stopping
# 313/313 [==============================] - 3s 10ms/step
#
#  Test_acc для BatchNormalization в обоих слоях =  0.5908

# %% [markdown]
# **Вывод:** BatchNormalization не дал прироста точности нейросети, также размещение BatchNormalization в свёрточном слое замедляет  работу нейросети. Но при этом accuracy в сети без BatchNormalization оказалось выше: 0.6078.
#
# Можно сделать вывод, что на текущей схеме нейросети, применение BatchNormalization не даёт преимуществ.

# %% [markdown]
# ### 5. Поиск такого значения batch_size, при котором модель быстрее достигает точности 55%.

# %%
callback = keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                         mode='max', min_delta=0.001,
                                         patience = 3)

# %%
batch_size = [4, 8, 16, 32, 64, 128, 256, 512, 1024]

# %%
for batch in tqdm(batch_size):
    print('----------------------------')
    print('batch_size =', batch)
    model = Sequential([
        layers.Conv2D(filters=10,
                      kernel_size=(3, 3),
                      padding='same',
                      activation='relu',
                      input_shape=(32, 32, 3)),
        layers.MaxPool2D(pool_size=(2, 2), padding='valid'),
        layers.Flatten(),
        layers.Dense(100, activation='relu'),
        layers.Dense(10, activation='softmax')])
    
    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])
    
    history = model.fit(X_train,
               y_train,
               batch_size = batch,
               validation_split=0.2,
               verbose=3,
               epochs=50,
               callbacks = callback,
               validation_data=[X_val, y_val])
    
    plt.plot(model.history.history['accuracy'],label='Train Accuracy')
    plt.plot(model.history.history['val_accuracy'],label='Test Accuracy')
    plt.legend()
    plt.title(f'График accuracy на batch_size = {batch}')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# ----------------------------
# batch_size = 4
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# ----------------------------
# batch_size = 8
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# ----------------------------
# batch_size = 16
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# ----------------------------
# batch_size = 32
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# ----------------------------
# batch_size = 64
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# ----------------------------
# batch_size = 128
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# ----------------------------
# batch_size = 256
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# ----------------------------
# batch_size = 512
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# ----------------------------
# batch_size = 1024
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50

# %% [markdown]
# **Вывод** при batch_size = 4 и 8 accuracy = 55% было достигнуто уже на epoch = 2. С batch_size = 16 наблюдается увеличение числа epoch для достижения необходимого accuracy, а с batch_size = 128 необходимый уровень не достигается

# %% [markdown]
# ### 6. Поиск комбинации метода обучения и нормализации, при которой сеть имеет наилучшую кривую обучения.

# %% [markdown]
# Не реализовано

# %% [markdown]
# ### 7. Обучение большой свёрточной сети, которая даст на тестовой выборке accuracy больше 80%

# %%
callback_final = keras.callbacks.EarlyStopping(monitor='loss', patience=3)

# %%
C = Sequential([
    layers.Conv2D(filters=32,
                  kernel_size=(3, 3),
                  padding='same',
                  activation='relu',
                  input_shape=(32, 32, 3)),
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size=(2, 2), padding='valid'),
    layers.Dropout(0.2),
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.3),
    layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.4),
    layers.Flatten(),
    layers.Dense(100, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')])

final_model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

final_model.fit(X_train,
                y_train,
                batch_size=16,
                validation_split=0.2,
                verbose=2,
                epochs=100,
                callbacks = callbacks,
                validation_data=[X_val, y_val])
# Out:
# Epoch 1/100
# 2500/2500 - 146s - loss: 1.8540 - accuracy: 0.3533 - val_loss: 1.4974 - val_accuracy: 0.4612 - lr: 0.0100 - 146s/epoch - 58ms/step
# Epoch 2/100
# 2500/2500 - 143s - loss: 1.4341 - accuracy: 0.4838 - val_loss: 1.2849 - val_accuracy: 0.5367 - lr: 0.0100 - 143s/epoch - 57ms/step
# Epoch 3/100
# 2500/2500 - 144s - loss: 1.2803 - accuracy: 0.5444 - val_loss: 1.0230 - val_accuracy: 0.6368 - lr: 0.0100 - 144s/epoch - 58ms/step
# Epoch 4/100
# 2500/2500 - 144s - loss: 1.1663 - accuracy: 0.5895 - val_loss: 1.0337 - val_accuracy: 0.6317 - lr: 0.0100 - 144s/epoch - 58ms/step
# Epoch 5/100
# 2500/2500 - 143s - loss: 1.0832 - accuracy: 0.6193 - val_loss: 1.1819 - val_accuracy: 0.5845 - lr: 0.0100 - 143s/epoch - 57ms/step
# Epoch 6/100
# 2500/2500 - 153s - loss: 1.0157 - accuracy: 0.6453 - val_loss: 0.8195 - val_accuracy: 0.7153 - lr: 0.0100 - 153s/epoch - 61ms/step
# Epoch 7/100
# 2500/2500 - 143s - loss: 0.9555 - accuracy: 0.6679 - val_loss: 0.7789 - val_accuracy: 0.7243 - lr: 0.0100 - 143s/epoch - 57ms/step
# Epoch 8/100
# 2500/2500 - 145s - loss: 0.9183 - accuracy: 0.6785 - val_loss: 0.8539 - val_accuracy: 0.6995 - lr: 0.0100 - 145s/epoch - 58ms/step
# Epoch 9/100
# 2500/2500 - 144s - loss: 0.8763 - accuracy: 0.6967 - val_loss: 0.7422 - val_accuracy: 0.7402 - lr: 0.0100 - 144s/epoch - 58ms/step
# Epoch 10/100
# 2500/2500 - 144s - loss: 0.8504 - accuracy: 0.7067 - val_loss: 0.7314 - val_accuracy: 0.7453 - lr: 0.0100 - 144s/epoch - 58ms/step
# Epoch 11/100
# 2500/2500 - 144s - loss: 0.8198 - accuracy: 0.7151 - val_loss: 0.8557 - val_accuracy: 0.7050 - lr: 0.0090 - 144s/epoch - 58ms/step
# Epoch 12/100
# 2500/2500 - 142s - loss: 0.7862 - accuracy: 0.7299 - val_loss: 0.6819 - val_accuracy: 0.7605 - lr: 0.0082 - 142s/epoch - 57ms/step
# Epoch 13/100
# 2500/2500 - 145s - loss: 0.7686 - accuracy: 0.7362 - val_loss: 0.7728 - val_accuracy: 0.7322 - lr: 0.0074 - 145s/epoch - 58ms/step
# Epoch 14/100
# 2500/2500 - 143s - loss: 0.7470 - accuracy: 0.7402 - val_loss: 0.6465 - val_accuracy: 0.7790 - lr: 0.0067 - 143s/epoch - 57ms/step
# Epoch 15/100
# 2500/2500 - 145s - loss: 0.7191 - accuracy: 0.7518 - val_loss: 0.6162 - val_accuracy: 0.7876 - lr: 0.0061 - 145s/epoch - 58ms/step
# Epoch 16/100
# 2500/2500 - 143s - loss: 0.6997 - accuracy: 0.7592 - val_loss: 0.6479 - val_accuracy: 0.7751 - lr: 0.0055 - 143s/epoch - 57ms/step
# Epoch 17/100
# 2500/2500 - 145s - loss: 0.6889 - accuracy: 0.7626 - val_loss: 0.5697 - val_accuracy: 0.8011 - lr: 0.0050 - 145s/epoch - 58ms/step
# Epoch 18/100
# 2500/2500 - 143s - loss: 0.6725 - accuracy: 0.7695 - val_loss: 0.5737 - val_accuracy: 0.8009 - lr: 0.0045 - 143s/epoch - 57ms/step
# Epoch 19/100
# 2500/2500 - 144s - loss: 0.6619 - accuracy: 0.7728 - val_loss: 0.5542 - val_accuracy: 0.8058 - lr: 0.0041 - 144s/epoch - 58ms/step
# Epoch 20/100
# 2500/2500 - 143s - loss: 0.6513 - accuracy: 0.7769 - val_loss: 0.5896 - val_accuracy: 0.7964 - lr: 0.0037 - 143s/epoch - 57ms/step
# Epoch 21/100
# 2500/2500 - 145s - loss: 0.6454 - accuracy: 0.7796 - val_loss: 0.5990 - val_accuracy: 0.7923 - lr: 0.0033 - 145s/epoch - 58ms/step
# Epoch 22/100
# 2500/2500 - 144s - loss: 0.6302 - accuracy: 0.7846 - val_loss: 0.5552 - val_accuracy: 0.8085 - lr: 0.0030 - 144s/epoch - 58ms/step
# Epoch 23/100
# 2500/2500 - 144s - loss: 0.6214 - accuracy: 0.7874 - val_loss: 0.5551 - val_accuracy: 0.8116 - lr: 0.0027 - 144s/epoch - 58ms/step
# Epoch 24/100
# 2500/2500 - 143s - loss: 0.6070 - accuracy: 0.7908 - val_loss: 0.5549 - val_accuracy: 0.8070 - lr: 0.0025 - 143s/epoch - 57ms/step
# Epoch 25/100
# 2500/2500 - 145s - loss: 0.6039 - accuracy: 0.7915 - val_loss: 0.5465 - val_accuracy: 0.8132 - lr: 0.0022 - 145s/epoch - 58ms/step
# Epoch 26/100
# 2500/2500 - 143s - loss: 0.5963 - accuracy: 0.7952 - val_loss: 0.5226 - val_accuracy: 0.8179 - lr: 0.0020 - 143s/epoch - 57ms/step
# Epoch 27/100
# 2500/2500 - 145s - loss: 0.5946 - accuracy: 0.7957 - val_loss: 0.5195 - val_accuracy: 0.8202 - lr: 0.0018 - 145s/epoch - 58ms/step
# Epoch 28/100
# 2500/2500 - 143s - loss: 0.5833 - accuracy: 0.7988 - val_loss: 0.5521 - val_accuracy: 0.8095 - lr: 0.0017 - 143s/epoch - 57ms/step
# Epoch 29/100
# 2500/2500 - 145s - loss: 0.5796 - accuracy: 0.8021 - val_loss: 0.5226 - val_accuracy: 0.8184 - lr: 0.0015 - 145s/epoch - 58ms/step
# Epoch 30/100
# 2500/2500 - 143s - loss: 0.5719 - accuracy: 0.8051 - val_loss: 0.5265 - val_accuracy: 0.8179 - lr: 0.0014 - 143s/epoch - 57ms/step
# Epoch 31/100
# 2500/2500 - 145s - loss: 0.5729 - accuracy: 0.8036 - val_loss: 0.5297 - val_accuracy: 0.8179 - lr: 0.0012 - 145s/epoch - 58ms/step
# Epoch 32/100
# 2500/2500 - 143s - loss: 0.5681 - accuracy: 0.8045 - val_loss: 0.5268 - val_accuracy: 0.8161 - lr: 0.0011 - 143s/epoch - 57ms/step
# Epoch 33/100
# 2500/2500 - 145s - loss: 0.5695 - accuracy: 0.8041 - val_loss: 0.5276 - val_accuracy: 0.8189 - lr: 0.0010 - 145s/epoch - 58ms/step
# Epoch 34/100
# 2500/2500 - 144s - loss: 0.5659 - accuracy: 0.8076 - val_loss: 0.5112 - val_accuracy: 0.8237 - lr: 9.0718e-04 - 144s/epoch - 58ms/step
# Epoch 35/100
# 2500/2500 - 145s - loss: 0.5626 - accuracy: 0.8077 - val_loss: 0.5112 - val_accuracy: 0.8221 - lr: 8.2085e-04 - 145s/epoch - 58ms/step
# Epoch 36/100
# 2500/2500 - 145s - loss: 0.5520 - accuracy: 0.8100 - val_loss: 0.5208 - val_accuracy: 0.8211 - lr: 7.4274e-04 - 145s/epoch - 58ms/step
# Epoch 37/100
# 2500/2500 - 145s - loss: 0.5548 - accuracy: 0.8107 - val_loss: 0.5135 - val_accuracy: 0.8236 - lr: 6.7206e-04 - 145s/epoch - 58ms/step
# Epoch 38/100
# 2500/2500 - 144s - loss: 0.5479 - accuracy: 0.8103 - val_loss: 0.5126 - val_accuracy: 0.8247 - lr: 6.0810e-04 - 144s/epoch - 57ms/step
# Epoch 39/100
# 2500/2500 - 145s - loss: 0.5486 - accuracy: 0.8106 - val_loss: 0.5195 - val_accuracy: 0.8222 - lr: 5.5023e-04 - 145s/epoch - 58ms/step
# Epoch 40/100
# 2500/2500 - 145s - loss: 0.5419 - accuracy: 0.8135 - val_loss: 0.5098 - val_accuracy: 0.8257 - lr: 4.9787e-04 - 145s/epoch - 58ms/step
# Epoch 41/100
# 2500/2500 - 143s - loss: 0.5482 - accuracy: 0.8107 - val_loss: 0.5118 - val_accuracy: 0.8251 - lr: 4.5049e-04 - 143s/epoch - 57ms/step
# Epoch 42/100
# 2500/2500 - 145s - loss: 0.5460 - accuracy: 0.8137 - val_loss: 0.5111 - val_accuracy: 0.8255 - lr: 4.0762e-04 - 145s/epoch - 58ms/step
# Epoch 43/100
# 2500/2500 - 145s - loss: 0.5388 - accuracy: 0.8156 - val_loss: 0.5087 - val_accuracy: 0.8234 - lr: 3.6883e-04 - 145s/epoch - 58ms/step
# Epoch 44/100
# 2500/2500 - 145s - loss: 0.5432 - accuracy: 0.8132 - val_loss: 0.5136 - val_accuracy: 0.8240 - lr: 3.3373e-04 - 145s/epoch - 58ms/step
# Epoch 45/100
# 2500/2500 - 145s - loss: 0.5440 - accuracy: 0.8149 - val_loss: 0.5035 - val_accuracy: 0.8266 - lr: 3.0197e-04 - 145s/epoch - 58ms/step
# Epoch 46/100
# 2500/2500 - 145s - loss: 0.5326 - accuracy: 0.8168 - val_loss: 0.5026 - val_accuracy: 0.8273 - lr: 2.7324e-04 - 145s/epoch - 58ms/step
# Epoch 47/100
# 2500/2500 - 143s - loss: 0.5414 - accuracy: 0.8136 - val_loss: 0.5100 - val_accuracy: 0.8274 - lr: 2.4724e-04 - 143s/epoch - 57ms/step
# Epoch 48/100
# 2500/2500 - 145s - loss: 0.5356 - accuracy: 0.8166 - val_loss: 0.5050 - val_accuracy: 0.8285 - lr: 2.2371e-04 - 145s/epoch - 58ms/step
# Epoch 49/100
# 2500/2500 - 145s - loss: 0.5400 - accuracy: 0.8145 - val_loss: 0.5064 - val_accuracy: 0.8272 - lr: 2.0242e-04 - 145s/epoch - 58ms/step

# %%
y_pred = [np.argmax(prob) for prob in final_model.predict(X_test)]
test_acc = accuracy_score(y_test, y_pred)
print("\n Test_acc =", test_acc)
if test_acc > 0.8:
    print("Это победа!")
# Out:
# 313/313 [==============================] - 12s 38ms/step
#
#  Test_acc = 0.8261
# Это победа!

# %% [markdown]
# ### Выводы:
# В работе было исследование влияние различных параметров на точность работы свёрточной нейросети.
# Была создана многослойная свёрточная нейросеть с применением батч нормализации с точностью выше 80%

# %% [markdown]
# ### Для проверяющего:
# Порекомендуйте материалы для реализации пункта №6 "Поиск комбинации метода обучения и нормализации, при которой сеть имеет наилучшую кривую обучения."
